# %% [markdown]
# # Welcome to `arcospy`!
#
# arcospy is the unofficial python equivalent of the R arcos package maintained by the [Washington Post](https://github.com/wpinvestigative/arcos). Here we will demonstrate a few basic commands of the arcospy package and hint at some advanced usage.

# %% [markdown]
# # Understanding the available commands.
#
# `arcospy` shares the same functionality as `arcos`, i.e. all the functions have inherited same name. The functions are grouped into the following types:
#
# - Summarized: retrieve aggregated data at either the county or state level
# - Raw: returns raw data at either the county or state level (NOTE: these functions will return large amounts of data)
# - Supplemental: retrieve supplemental information on the reporting pharmacies that contribute to ARCOS
#
# We demonstrate a few basic functions here and introduce how to make the data spatial.

# %% [markdown]
# # Regarding API keys

# %% [markdown]
# In this demo notebook we use the generic key 'WaPo'. However, more API keys are available [here](https://github.com/wpinvestigative/arcos-api/blob/master/keys/keys.txt). As per the R arcos warning regarding keys:
#
# >"...We reserve the right to blacklist these and invite users to sign up for their own individual keys in the future if the need arises. ... If you publish anything based on this data set, please credit The Washington Post, link to the original source, and send us an email when you’ve hit publish. We want to learn what you discover and will attempt to link to your work as part of cataloguing the impact of this project." (Full statement regarding keys [here.](https://github.com/wpinvestigative/arcos)

# %% [markdown]
# # Installing and loading `arcospy`

# %%
# !pip install arcospy
# Out:
# Requirement already satisfied: arcospy in c:\programdata\anaconda3\lib\site-packages (0.0.6)

# %%
import arcospy

# %%
# Print the available functions
help(arcospy)
# Out:
# Help on package arcospy:
#
# NAME
#     arcospy
#
# PACKAGE CONTENTS
#     arcospy
#
# FUNCTIONS
#     buyer_addresses(county='', state='', key='')
#
#     buyer_details(county='', state='', key='')
#
#     combined_buyer_annual(county='', state='', key='')
#
#     combined_buyer_monthly(county='', state='', year='', key='')
#
#     county_population(county='', state='', key='')
#
#     county_raw(county='', state='', key='')
#
#     county_raw_fips(fips='', key='')
#
#     not_pharmacies(key='')
#
#     pharm_cbsa(geoid='', county='', state='', key='')
#
#     pharm_counties(county='', state='', key='')
#
#     pharm_latlon(county='', state='', key='')
#
#     pharm_tracts(county='', state='', key='')
#
#     pharmacy_raw(buyer_dea_no='', key='')
#
#     raw_data(key='')
#
#     reporter_addresses(county='', state='', key='')
#
#     state_population(state='', key='')
#
#     summarized_county_annual(county='', state='', key='')
#
#     summarized_county_monthly(county='', state='', key='')
#
#     total_distributors_county(county='', state='', key='')
#
#     total_distributors_state(county='', state='', key='')
#
#     total_manufacturers_county(county='', state='', key='')
#
#     total_manufacturers_state(county='', state='', key='')
#
#     total_pharmacies_county(county='', state='', key='')
#
#     total_pharmacies_state(county='', state='', key='')
#
# FILE
#     c:\programdata\anaconda3\lib\site-packages\arcospy\__init__.py

# %% [markdown]
# # Demonstrating a summarized command

# %% [markdown]
# Here we will retrieve annual summarized pill totals for Hennepin County, Minnesota.

# %%
arcospy.summarized_county_annual(county = 'Hennepin', state = 'MN', key = 'WaPo')
# Out:
#   BUYER_COUNTY BUYER_STATE  year  count  DOSAGE_UNIT countyfips
# 0     HENNEPIN          MN  2006  47956     22360536      27053
# 1     HENNEPIN          MN  2007  51518     24776053      27053
# 2     HENNEPIN          MN  2008  56075     26514566      27053
# 3     HENNEPIN          MN  2009  62698     28256003      27053
# 4     HENNEPIN          MN  2010  69330     30351931      27053
# 5     HENNEPIN          MN  2011  72163     31499006      27053
# 6     HENNEPIN          MN  2012  75186     31673650      27053

# %% [markdown]
# # Demonstrating a raw command

# %% [markdown]
# We can the raw-equivalent of the above command to get the data at the reporter level. Note the output size of the dataframe - it is quite large (434926 rows × 42 columns) and this is for only one county!

# %%
arcospy.county_raw(county = 'Hennepin', state = 'MN', key = 'WaPo')
# Out:
#        REPORTER_DEA_NO REPORTER_BUS_ACT                 REPORTER_NAME  \
# 0            RD0203365      DISTRIBUTOR  D&K HEALTHCARE RESOURCES INC
# 1            RD0203365      DISTRIBUTOR  D&K HEALTHCARE RESOURCES INC
# 2            RD0244842      DISTRIBUTOR                   DAKOTA DRUG
# 3            RD0244842      DISTRIBUTOR                   DAKOTA DRUG
# 4            RD0244842      DISTRIBUTOR                   DAKOTA DRUG
# ...                ...              ...                           ...
# 434921       RA0287020      DISTRIBUTOR      ANDA PHARMACEUTICALS INC
# 434922       RA0287020      DISTRIBUTOR      ANDA PHARMACEUTICALS INC
# 434923       RA0287020      DISTRIBUTOR      ANDA PHARMACEUTICALS INC
# 434924       RA0287020      DISTRIBUTOR      ANDA PHARMACEUTICALS INC
# 434925       RA0287020      DISTRIBUTOR      ANDA PHARMACEUTICALS INC
#
#        REPORTER_ADDL_CO_INFO       REPORTER_ADDRESS1 REPORTER_ADDRESS2  \
# 0                       null  800 NORTH THIRD STREET              null
# 1                       null  800 NORTH THIRD STREET              null
# 2                       null     4121 12TH AVENUE NW              null
# 3                       null     4121 12TH AVENUE NW              null
# 4                       null     4121 12TH AVENUE NW              null
# ...                      ...                     ...               ...
# 434921                  null     6500 ADELAIDE COURT              null
# 434922                  null     6500 ADELAIDE COURT              null
# 434923                  null     6500 ADELAIDE COURT              null
# 434924                  null     6500 ADELAIDE COURT              null
# 434925                  null     6500 ADELAIDE COURT              null
#
#        REPORTER_CITY REPORTER_STATE  REPORTER_ZIP REPORTER_COUNTY  ...  \
# 0        MINNEAPOLIS             MN         55401        HENNEPIN  ...
# 1        MINNEAPOLIS             MN         55401        HENNEPIN  ...
# 2              FARGO             ND         58102            CASS  ...
# 3              FARGO             ND         58102            CASS  ...
# 4              FARGO             ND         58102            CASS  ...
# ...              ...            ...           ...             ...  ...
# 434921     GROVEPORT             OH         43125        FRANKLIN  ...
# 434922     GROVEPORT             OH         43125        FRANKLIN  ...
# 434923     GROVEPORT             OH         43125        FRANKLIN  ...
# 434924     GROVEPORT             OH         43125        FRANKLIN  ...
# 434925     GROVEPORT             OH         43125        FRANKLIN  ...
#
#        DOSAGE_UNIT TRANSACTION_ID                          Product_Name  \
# 0            500.0      602001434  OXYCODONE HCL/ACETAMINOPHEN 5MG/325M
# 1            100.0      601005570  OXYCODONE HYDROCHLORIDE CR 20MG TABL
# 2            200.0           4789  OXYCODONE HCL/ACETAMINOPHEN 5MG/325M
# 3            100.0           4521  HYDROCODO.BIT/APAP 7.5MG/750MG USP T
# 4            100.0           4530  HYDROCODO.BIT/APAP 7.5MG/750MG USP T
# ...            ...            ...                                   ...
# 434921       300.0      912055994  OXYCODONE HCL/ACETAMINOPHEN TABS 10M
# 434922       100.0     1007018207        OXYCODONE HCL 30MG USP TABLETS
# 434923       300.0     1008018626         OXYCODONE HCL 10MG CR TABLETS
# 434924       200.0     1206034401  HYDROCODONE/IBUPROFEN 7.5MG/200MG TA
# 434925       300.0     1209014571  OXYCODONE HCL/ACETAMINOPHEN 7.5MG/32
#
#                                 Ingredient_Name Measure MME_Conversion_Factor  \
# 0                       OXYCODONE HYDROCHLORIDE     TAB                   1.5
# 1                       OXYCODONE HYDROCHLORIDE     TAB                   1.5
# 2                       OXYCODONE HYDROCHLORIDE     TAB                   1.5
# 3       HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# 4       HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# ...                                         ...     ...                   ...
# 434921                  OXYCODONE HYDROCHLORIDE     TAB                   1.5
# 434922                  OXYCODONE HYDROCHLORIDE     TAB                   1.5
# 434923                  OXYCODONE HYDROCHLORIDE     TAB                   1.5
# 434924  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# 434925                  OXYCODONE HYDROCHLORIDE     TAB                   1.5
#
#                       Combined_Labeler_Name  \
# 0                                SpecGx LLC
# 1                      Actavis Pharma, Inc.
# 2                        Par Pharmaceutical
# 3                                SpecGx LLC
# 4                                SpecGx LLC
# ...                                     ...
# 434921           Amneal Pharmaceuticals LLC
# 434922                   Par Pharmaceutical
# 434923  Sun Pharmaceutical Industries, Inc.
# 434924           Amneal Pharmaceuticals LLC
# 434925                           SpecGx LLC
#
#                        Revised_Company_Name             Reporter_family  \
# 0                              Mallinckrodt  D & K Healthcare Resources
# 1                          Purdue Pharma LP  D & K Healthcare Resources
# 2                Endo Pharmaceuticals, Inc.                 Dakota Drug
# 3                              Mallinckrodt                 Dakota Drug
# 4                              Mallinckrodt                 Dakota Drug
# ...                                     ...                         ...
# 434921         Amneal Pharmaceuticals, Inc.                   Anda, Inc
# 434922           Endo Pharmaceuticals, Inc.                   Anda, Inc
# 434923  Sun Pharmaceutical Industries, Inc.                   Anda, Inc
# 434924         Amneal Pharmaceuticals, Inc.                   Anda, Inc
# 434925                         Mallinckrodt                   Anda, Inc
#
#        dos_str
# 0          5.0
# 1         20.0
# 2          5.0
# 3          7.5
# 4          7.5
# ...        ...
# 434921    10.0
# 434922    30.0
# 434923    10.0
# 434924     7.5
# 434925     7.5
#
# [434926 rows x 42 columns]

# %% [markdown]
# # Demonstrating a supplemental command

# %% [markdown]
# What if you wanted to analyze the data at the pharmacy level as a point process? We can get the latitude and longitude of the pharmacies below:

# %%
arcospy.pharm_latlon(county = 'Hennepin', state = 'MN', key = 'WaPo')
# Out:
#     BUYER_DEA_NO BUYER_STATE BUYER_COUNTY      lat      lon
# 0      FV1004124          MN     HENNEPIN  45.0311 -93.3139
# 1      BM8846050          MN     HENNEPIN  44.9998 -93.2885
# 2      BW0218405          MN     HENNEPIN  44.9243 -93.2622
# 3      BC7024689          MN     HENNEPIN  44.9669 -93.3543
# 4      AG6630710          MN     HENNEPIN  44.9663 -93.3446
# ..           ...         ...          ...      ...      ...
# 291    FS1238282          MN     HENNEPIN  44.9593 -93.3699
# 292    BF9046889          MN     HENNEPIN  45.0200 -93.2367
# 293    BP8937368          MN     HENNEPIN  45.0197 -93.4853
# 294    FP0183183          MN     HENNEPIN  45.0197 -93.4853
# 295    BS6576322          MN     HENNEPIN  45.0663 -93.4425
#
# [296 rows x 5 columns]

# %% [markdown]
# However, as raised on the Github issues page [here](https://github.com/wpinvestigative/arcos/issues/3), it may be useful to clip (or at least create an indicator variable for) the pharmacies that fall outside the state.

# %% [markdown]
# # Making the data spatial

# %% [markdown]
# One of the most interesting possibilites of this data is its readiness for spatial analysis. However, the WP ARCOS API does not provide any shapefiles so we need to source those from somewhere. There are a few options for this:
#
# - Manually download shapefiles and import them using geopandas
# - Gather shapefiles via cenpy or some other python package
# - Directly import shapefiles from a designated URL
#
# Here we use cenpy for a quick demonstration, but users interested in conducting year-specific analyses, especially for the years 2006-2009, might try sourcing shapefiles from the U.S. Census Bureau or the tidycensus package in R.
#
# Here we will make use of the official U.S. Census 2010 county-level shapefiles for Minnesota, available [here](https://www2.census.gov/geo/pvs/tiger2010st/27_Minnesota/27/tl_2010_27_county10.zip). Please note these files were downloaded, unzipped, and then manually imported (i.e. the first option above).

# %%
# Download summarized data for Minnesota
mn_summarized = arcospy.summarized_county_annual(state = 'MN', key = 'WaPo')

mn_summarized.head()
# Out:
#   BUYER_COUNTY BUYER_STATE  year  count  DOSAGE_UNIT countyfips
# 0       AITKIN          MN  2006   1227       357900      27001
# 1       AITKIN          MN  2007   1456       394400      27001
# 2       AITKIN          MN  2008   1481       457700      27001
# 3       AITKIN          MN  2009   1787       530300      27001
# 4       AITKIN          MN  2010   2158       580320      27001

# %%
mn_summarized.dtypes
# Out:
# BUYER_COUNTY    object
# BUYER_STATE     object
# year             int64
# count            int64
# DOSAGE_UNIT      int64
# countyfips      object
# dtype: object

# %%
# Restrict the data to the year of 2010
mn_2010 = mn_summarized[mn_summarized['year']==2010]

mn_2010.head()
# Out:
#    BUYER_COUNTY BUYER_STATE  year  count  DOSAGE_UNIT countyfips
# 4        AITKIN          MN  2010   2158       580320      27001
# 11        ANOKA          MN  2010  21430      9176630      27003
# 18       BECKER          MN  2010   3093       699080      27005
# 25     BELTRAMI          MN  2010   3009       763450      27007
# 32       BENTON          MN  2010   2394       712740      27009

# %% [markdown]
# Now we load in the MN 2010 county shapefiles using geopandas.

# %%
import geopandas as gpd

# %%
mn_shp = gpd.read_file('C:/Users/USER/Desktop/mn/tl_2010_27_county10.shp')

# %% [markdown]
# Create a test plot to ensure the file renders.

# %%
mn_shp.plot()

# %% [markdown]
# Let's take a look at the data characteristics to understand what columns we are going to merge on.

# %%
mn_shp.head()
# Out:
#   STATEFP10 COUNTYFP10 COUNTYNS10 GEOID10             NAME10  \
# 0        27        061   00659476   27061             Itasca
# 1        27        077   00659483   27077  Lake of the Woods
# 2        27        025   00659458   27025            Chisago
# 3        27        113   00659502   27113         Pennington
# 4        27        085   00659491   27085             McLeod
#
#                  NAMELSAD10 LSAD10 CLASSFP10 MTFCC10 CSAFP10 CBSAFP10  \
# 0             Itasca County     06        H1   G4020    None     None
# 1  Lake of the Woods County     06        H1   G4020    None     None
# 2            Chisago County     06        H1   G4020     378    33460
# 3         Pennington County     06        H1   G4020    None     None
# 4             McLeod County     06        H1   G4020     378    26780
#
#   METDIVFP10 FUNCSTAT10     ALAND10    AWATER10   INTPTLAT10    INTPTLON10  \
# 0       None          A  6909367239   674021189  +47.4908429  -093.6131284
# 1       None          A  3361466280  1234895902  +48.7681003  -094.9046335
# 2       None          A  1074486739    71347419  +45.5054439  -092.9038486
# 3       None          A  1596909321     4351512  +48.0692470  -096.0377254
# 4       None          A  1272903896    36406906  +44.8216437  -094.2723203
#
#                                             geometry
# 0  POLYGON ((-93.06349 47.633138, -93.063508 47.6...
# 1  POLYGON ((-95.09032099999999 48.800006, -95.09...
# 2  POLYGON ((-93.01864499999999 45.367717, -93.01...
# 3  POLYGON ((-95.72251999999999 48.172987, -95.71...
# 4  POLYGON ((-94.497912 44.726544, -94.497922 44....

# %% [markdown]
# Looks like GEOID10 is the ticket! We can quickly rename GEOID10 to countyfips to match the column returned by the `arcospy` function.

# %%
mn_shp = mn_shp.rename(columns={"GEOID10": "countyfips"})

# %% [markdown]
# But are the columns the same dtypes?

# %%
mn_shp.dtypes
# Out:
# STATEFP10     object
# COUNTYFP10    object
# COUNTYNS10    object
# countyfips    object
# NAME10        object
# NAMELSAD10    object
# LSAD10        object
# CLASSFP10     object
# MTFCC10       object
# CSAFP10       object
# CBSAFP10      object
# METDIVFP10    object
# FUNCSTAT10    object
# ALAND10        int64
# AWATER10       int64
# INTPTLAT10    object
# INTPTLON10    object
# geometry      object
# dtype: object

# %% [markdown]
# Let's now join the two files on GEOID10.

# %%
mn_2010_spatial = mn_shp.merge(mn_2010, on='countyfips')

# %% [markdown]
# Now we can plot the total dosage units per county in 2010 and make some small aesthetic changes. I follow [this StackExchange](https://stackoverflow.com/questions/54236083/geopandas-reduce-legend-size-and-remove-white-space-below-map) post to add a 'normal' sized color ramp.

# %%
# Load matplotlibes
import matplotlib.pyplot as plt

# Define colors
colormap = "plasma" 

# Draw the base percent population age 0-5 map
ax = mn_2010_spatial.plot(column='DOSAGE_UNIT',
                          cmap = colormap)

ax.set_axis_off()
ax.set_title("Total dosage units of major prescription opioids by county in MN in 2010 (data source: ARCOS)")

fig = ax.get_figure()
cbax = fig.add_axes([0.95, 0.3, 0.03, 0.39])   
cbax.set_title('Total Dosage Units')

sm = plt.cm.ScalarMappable(cmap=colormap, \
                norm=plt.Normalize(vmin=min(mn_2010_spatial.DOSAGE_UNIT), vmax=max(mn_2010_spatial.DOSAGE_UNIT)))

sm._A = []
fig.colorbar(sm, cax=cbax, format="%d")

plt.show()

# %% [markdown]
# Perhaps not the best color choice! Can you do better? Happy mapping!
